# %% [markdown]
# <a href="https://colab.research.google.com/github/woodskd24/ModernUSAHealthcare/blob/main/Drug_Use_disorders_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Data From https://data.world/vizzup/mental-health-depression-disorder-data/workspace/file?filename=Mental+health+Depression+disorder+Data.xlsx
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/MHPred.csv')
df
# Out:
#     Year  Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# 0   1990           0.340897              0.653706              0.468676
# 1   1991           0.338913              0.653953              0.473575
# 2   1992           0.337343              0.654205              0.478610
# 3   1993           0.336207              0.654431              0.483539
# 4   1994           0.335536              0.654620              0.488235
# 5   1995           0.335363              0.654721              0.492368
# 6   1996           0.335806              0.654749              0.496752
# 7   1997           0.336797              0.654720              0.501560
# 8   1998           0.338085              0.654658              0.506483
# 9   1999           0.339410              0.654564              0.511072
# 10  2000           0.340512              0.654443              0.514863
# 11  2001           0.341186              0.654371              0.518306
# 12  2002           0.341483              0.654349              0.522170
# 13  2003           0.341535              0.654343              0.526130
# 14  2004           0.341472              0.654313              0.529332
# 15  2005           0.341427              0.654228              0.531157
# 16  2006           0.341031              0.654080              0.532178
# 17  2007           0.340069              0.653896              0.533067
# 18  2008           0.338901              0.653691              0.533768
# 19  2009           0.337887              0.653468              0.534175
# 20  2010           0.337390              0.653247              0.534076
# 21  2011           0.337190              0.653008              0.533199
# 22  2012           0.336852              0.652748              0.531514
# 23  2013           0.336404              0.652479              0.528946
# 24  2014           0.335860              0.652195              0.525990
# 25  2015           0.335243              0.651890              0.522109
# 26  2016           0.334578              0.651569              0.517728
# 27  2017           0.333890              0.651236              0.512844
#
#     Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# 0                6.576884                2.367794        4.677591
# 1                6.553351                2.345466        4.660871
# 2                6.536143                2.339515        4.651949
# 3                6.525536                2.347095        4.648701
# 4                6.522278                2.365738        4.649294
# 5                6.526489                2.392582        4.650869
# 6                6.578023                2.456048        4.662902
# 7                6.688847                2.564591        4.689154
# 8                6.818473                2.688823        4.720716
# 9                6.926351                2.800595        4.749991
# 10               6.971563                2.869426        4.766992
# 11               6.971995                2.905605        4.774031
# 12               6.971891                2.936109        4.778244
# 13               6.970935                2.962640        4.781680
# 14               6.968875                2.983414        4.785232
# 15               6.965249                2.998771        4.791258
# 16               6.937038                3.000826        4.793213
# 17               6.875454                2.989141        4.786623
# 18               6.801899                2.974336        4.776402
# 19               6.737790                2.966808        4.765950
# 20               6.704455                2.977144        4.761551
# 21               6.693384                3.007049        4.762322
# 22               6.682107                3.052340        4.765481
# 23               6.671047                3.110712        4.772422
# 24               6.660473                3.181115        4.782222
# 25               6.650662                3.262674        4.795954
# 26               6.642099                3.353142        4.813114
# 27               6.635055                3.452476        4.835610
#
#     Alcohol use disorders (%)
# 0                    2.173751
# 1                    2.139292
# 2                    2.107931
# 3                    2.080669
# 4                    2.058632
# 5                    2.042931
# 6                    2.033987
# 7                    2.030590
# 8                    2.031176
# 9                    2.034175
# 10                   2.038026
# 11                   2.043577
# 12                   2.051480
# 13                   2.059815
# 14                   2.066706
# 15                   2.070251
# 16                   2.063498
# 17                   2.045624
# 18                   2.023935
# 19                   2.005749
# 20                   1.998437
# 21                   1.999569
# 22                   2.001951
# 23                   2.005814
# 24                   2.011345
# 25                   2.018738
# 26                   2.028263
# 27                   2.040087

# %%
X = df[['Year']]
y = df['Drug use disorders (%)']

# %%
sns.scatterplot(x = "Year", y = "Drug use disorders (%)", data = df)

# %% [markdown]
# #Weka

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
import xgboost as xgb
from scipy.stats import uniform, randint

# %%
xgb = xgb.XGBRegressor(objective="reg:linear", random_state=42)

x1 = xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)])

y_pred1 = x1.predict(X_test)
# Out:
# [16:52:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:2.22246
# [1]	validation_0-rmse:2.02543
# [2]	validation_0-rmse:1.84732
# [3]	validation_0-rmse:1.68635
# [4]	validation_0-rmse:1.54089
# [5]	validation_0-rmse:1.39612
# [6]	validation_0-rmse:1.26693
# [7]	validation_0-rmse:1.14753
# [8]	validation_0-rmse:1.03706
# [9]	validation_0-rmse:0.936764
# [10]	validation_0-rmse:0.844058
# [11]	validation_0-rmse:0.764004
# [12]	validation_0-rmse:0.687229
# [13]	validation_0-rmse:0.617528
# [14]	validation_0-rmse:0.558547
# [15]	validation_0-rmse:0.50176
# [16]	validation_0-rmse:0.448971
# [17]	validation_0-rmse:0.405452
# [18]	validation_0-rmse:0.365886
# [19]	validation_0-rmse:0.326249
# [20]	validation_0-rmse:0.293375
# [21]	validation_0-rmse:0.263627
# [22]	validation_0-rmse:0.236145
# [23]	validation_0-rmse:0.212971
# [24]	validation_0-rmse:0.192199
# [25]	validation_0-rmse:0.172983
# [26]	validation_0-rmse:0.155522
# [27]	validation_0-rmse:0.134321
# [28]	validation_0-rmse:0.119936
# [29]	validation_0-rmse:0.107138
# [30]	validation_0-rmse:0.095216
# [31]	validation_0-rmse:0.08453
# [32]	validation_0-rmse:0.075189
# [33]	validation_0-rmse:0.066618
# [34]	validation_0-rmse:0.059164
# [35]	validation_0-rmse:0.052932
# [36]	validation_0-rmse:0.047281
# [37]	validation_0-rmse:0.042575
# [38]	validation_0-rmse:0.038496
# [39]	validation_0-rmse:0.035215
# [40]	validation_0-rmse:0.032601
# [41]	validation_0-rmse:0.030605
# [42]	validation_0-rmse:0.02922
# [43]	validation_0-rmse:0.028584
# [44]	validation_0-rmse:0.028287
# [45]	validation_0-rmse:0.028417
# [46]	validation_0-rmse:0.02887
# [47]	validation_0-rmse:0.02954
# [48]	validation_0-rmse:0.030374
# [49]	validation_0-rmse:0.0313
# [50]	validation_0-rmse:0.032224
# [51]	validation_0-rmse:0.033292
# [52]	validation_0-rmse:0.034354
# [53]	validation_0-rmse:0.035391
# [54]	validation_0-rmse:0.036388
# [55]	validation_0-rmse:0.037328
# [56]	validation_0-rmse:0.038339
# [57]	validation_0-rmse:0.039155
# [58]	validation_0-rmse:0.040033
# [59]	validation_0-rmse:0.040865
# [60]	validation_0-rmse:0.041618
# [61]	validation_0-rmse:0.042237
# [62]	validation_0-rmse:0.042908
# [63]	validation_0-rmse:0.043519
# [64]	validation_0-rmse:0.044071
# [65]	validation_0-rmse:0.04458
# [66]	validation_0-rmse:0.045065
# [67]	validation_0-rmse:0.045514
# [68]	validation_0-rmse:0.045948
# [69]	validation_0-rmse:0.046158
# [70]	validation_0-rmse:0.046543
# [71]	validation_0-rmse:0.046864
# [72]	validation_0-rmse:0.047186
# [73]	validation_0-rmse:0.047492
# [74]	validation_0-rmse:0.047774
# [75]	validation_0-rmse:0.047862
# [76]	validation_0-rmse:0.048116
# [77]	validation_0-rmse:0.048351
# [78]	validation_0-rmse:0.048536
# [79]	validation_0-rmse:0.048599
# [80]	validation_0-rmse:0.048768
# [81]	validation_0-rmse:0.048798
# [82]	validation_0-rmse:0.048976
# [83]	validation_0-rmse:0.049141
# [84]	validation_0-rmse:0.049271
# [85]	validation_0-rmse:0.049272
# [86]	validation_0-rmse:0.049291
# [87]	validation_0-rmse:0.04941
# [88]	validation_0-rmse:0.049408
# [89]	validation_0-rmse:0.049475
# [90]	validation_0-rmse:0.049539
# [91]	validation_0-rmse:0.0496
# [92]	validation_0-rmse:0.049658
# [93]	validation_0-rmse:0.049697
# [94]	validation_0-rmse:0.04975
# [95]	validation_0-rmse:0.049784
# [96]	validation_0-rmse:0.049832
# [97]	validation_0-rmse:0.049862
# [98]	validation_0-rmse:0.049906
# [99]	validation_0-rmse:0.049931

# %%
from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred1)
meanSqErr = metrics.mean_squared_error(y_test, y_pred1)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred1))
print('R squared: {:.2f}'.format(x1.score(X_train,y_train)*100))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# R squared: 99.99
# Mean Absolute Error: 0.037175816914550776
# Mean Square Error: 0.0024930451278354637
# Root Mean Square Error: 0.04993040284070882

# %%
print("Prediction for test set: {}".format(y_pred1))
# Out:
# Prediction for test set: [3.2609344 2.9810312 2.9810312 2.9810312 2.9963496 2.365885  3.110159
#  2.9053147 3.110159 ]

# %%
xG_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred1})
xG_diff.head()
# Out:
#     Actual value  Predicted value
# 24      3.181115         3.260934
# 17      2.989141         2.981031
# 19      2.966808         2.981031
# 20      2.977144         2.981031
# 14      2.983414         2.996350

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test, y_pred1, 'Red')
plt.show()
